# %% [markdown]
# # Chapter 1: Language Processing and Python

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# **Searching text or word using `concordance()`**

# %%
text1.concordance("monstrous")
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %% [markdown]
# **finding other words which appear in similar context by `similar()`**

# %%
text1.similar("monstrous")
# Out:
# imperial subtly impalpable pitiable curious abundant perilous
# trustworthy untoward singular lamentable few determined maddens
# horrible tyrannical lazy mystifying christian exasperate

# %%
text2.similar("monstrous")
# Out:
# very exceedingly so heartily a great good amazingly as sweet
# remarkably extremely vast

# %% [markdown]
# here in both books, the word `monstrous` is used differently.
# *Austen* used it in a positive way, even sometimes as an intensifier like word *very*

# %% [markdown]
# **The term `common_contexts()` allows us to examine the contexts that are shared by two or more words, such as *monstrous* and *very* **

# %%
text2.common_contexts(["monstrous","very"])
# Out:
# a_pretty is_pretty a_lucky am_glad be_glad

# %% [markdown]
# **`dispersion_plot()` plots the occurrence of each word as _parameters_ in a given _text_**

# %%
## text4 is inaugral corpus, contains speechs of people over last 220 years, joined end-to-end
text4.dispersion_plot(["citizens","democracy","freedom","duties","America"])

# %%
## Finding the length
len(text3)
# Out:
# 44764

# %% [markdown]
# `text3` has `44764` words and punctuation symbols or **TOKENS**(sequence of characters).

# %% [markdown]
# **Getting number of _unique_ `tokens` in text3**

# %%
print len(set(text3))
# print sorted(set(text3))
# Out:
# 2789

# %%
print len(text3)/len(set(text3)), 'is the average time a word was used.'
# Out:
# 16 is the average time a word was used.

# %%
## Can count number of times a particular word is used by count
text3.count('smote')
# Out:
# 5

# %%
## what percentage a text is taken by a word
100 * text3.count('the')/float(len(text3))
# Out:
# 5.386024483960325

# %%
def lexical_diversity(text):
    """average number of times a word was repeated in text"""
    return len(text)/len(set(text))

def word_percentage(word, text):
    """percentage of text a word is using"""
    return 100 * text.count(word)/float(len(text))

# %%
print 'text5:'
print 'lxical diversity: ',lexical_diversity(text5)
print 'percentage of "lol": ',word_percentage('lol',text5)
# Out:
# text5:
# lxical diversity:  7
# percentage of "lol":  1.56409686736

# %%
sent2
# Out:
# ['The',
#  'family',
#  'of',
#  'Dashwood',
#  'had',
#  'long',
#  'been',
#  'settled',
#  'in',
#  'Sussex',
#  '.']

# %% [markdown]
# ### Frequency Distribution

# %%
fdist1 = FreqDist(text1)

# %%
vocab = fdist1.keys()
# vocab[:50]

# %%
sorted(fdist1.items(), key=lambda x: x[1],reverse=True)
# Out:
# [(u',', 18713),
#  (u'the', 13721),
#  (u'.', 6862),
#  (u'of', 6536),
#  (u'and', 6024),
#  (u'a', 4569),
#  (u'to', 4542),
#  (u';', 4072),
#  (u'in', 3916),
#  (u'that', 2982),
#  (u"'", 2684),
#  (u'-', 2552),
#  (u'his', 2459),
#  (u'it', 2209),
#  (u'I', 2124),
#  (u's', 1739),
#  (u'is', 1695),
#  (u'he', 1661),
#  (u'with', 1659),
#  (u'was', 1632),
#  (u'as', 1620),
#  (u'"', 1478),
#  (u'all', 1462),
#  (u'for', 1414),
#  (u'this', 1280),
#  (u'!', 1269),
#  (u'at', 1231),
#  (u'by', 1137),
#  (u'but', 1113),
#  (u'not', 1103),
#  (u'--', 1070),
#  (u'him', 1058),
#  (u'from', 1052),
#  (u'be', 1030),
#  (u'on', 1005),
#  (u'so', 918),
#  (u'whale', 906),
#  (u'one', 889),
#  (u'you', 841),
#  (u'had', 767),
#  (u'have', 760),
#  (u'there', 715),
#  (u'But', 705),
#  (u'or', 697),
#  (u'were', 680),
#  (u'now', 646),
#  (u'which', 640),
#  (u'?', 637),
#  (u'me', 627),
#  (u'like', 624),
#  (u'The', 612),
#  (u'their', 612),
#  (u'they', 586),
#  (u'are', 586),
# ...

# %% [markdown]
# **Very first _substantial_ word (with meaning of its own) seems to be `whale`**
#
# So, `text1` may be about a `whale` or have avery close relation to it.

# %% [markdown]
# **Generating a cumulative_frequency plot**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.figure(figsize=(10,10))
fdist1.plot(50, cumulative=True)

# %%
## Trying to charachterize text5
fdist5 = FreqDist(text5)

# %%
sorted([w for w in fdist5.keys() if len(w)>=7 and fdist5[w]>7])
# Out:
# [u'#14-19teens',
#  u'#talkcity_adults',
#  u'((((((((((',
#  u'.......',
#  u'........',
#  u'<empty>',
#  u'Question',
#  u'Welcome',
#  u'actually',
#  u'already',
#  u'another',
#  u'anybody',
#  u'anything',
#  u'awesome',
#  u'because',
#  u'computer',
#  u'cute.-ass',
#  u'evening',
#  u'everyone',
#  u'females',
#  u'fingers',
#  u'football',
#  u'getting',
#  u'innocent',
#  u'kidding',
#  u'listening',
#  u'looking',
#  u'minutes',
#  u'morning',
#  u'myspace',
#  u'nothing',
#  u'profile',
#  u'remember',
#  u'seconds',
#  u'seriously',
#  u'someone',
#  u'something',
#  u'talking',
#  u'thought',
#  u'together',
#  u'tomorrow',
#  u'tonight',
#  u'watches',
#  u'watching',
#  u'welcome',
#  u'whisper',
#  u'without']

# %% [markdown]
# Above found the words which were frequently occuring and had length greater than 7.

# %% [markdown]
# #### Collocations and Bigrams
#
# **Collocations** are a sequence of words which occurs _together_ unusually often.
#
# **Bigrams** list of word-pairs

# %%
text5.collocations()
# Out:
# wanna chat; PART JOIN; MODE #14-19teens; JOIN PART; PART PART;
# cute.-ass MP3; MP3 player; JOIN JOIN; times .. .; ACTION watches; guys
# wanna; song lasts; last night; ACTION sits; -...)...- S.M.R.; Lime
# Player; Player 12%; dont know; lez gurls; long time

# %% [markdown]
# `text5` is probably data from a chat Room.

# %%
text4.collocations()
# Out:
# United States; fellow citizens; four years; years ago; Federal
# Government; General Government; American people; Vice President; Old
# World; Almighty God; Fellow citizens; Chief Magistrate; Chief Justice;
# God bless; every citizen; Indian tribes; public debt; one another;
# foreign nations; political parties

# %%
text8.collocations()
# Out:
# would like; medium build; social drinker; quiet nights; non smoker;
# long term; age open; Would like; easy going; financially secure; fun
# times; similar interests; Age open; weekends away; poss rship; well
# presented; never married; single mum; permanent relationship; slim
# build

# %% [markdown]
# **Collocations emerged are very specific to the texts**

# %%
## Dispersion Plot of 4 main characters in text2
fig = plt.figure(figsize=(10,10))
text2.dispersion_plot(["Elinor", "Marianne", "Edward","Willoughby"])

# %% [markdown]
# `Marianne` and `Willoughby` seems to be a couple, as they occur at same positions most frequently.
#
# `Maianne` and `Elinor` seems to closely related.

# %% [markdown]
# # Chap 2. Accessing Text Corpora and Lexical Resources
